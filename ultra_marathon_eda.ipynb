# %% [markdown]
# <a href="https://colab.research.google.com/github/hbetabessi/ultra-marathon-eda/blob/main/ultra_marathon_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df =pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# /tmp/ipython-input-2504010129.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
# see the data that's being imported

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                       22.0           4:51:39 h                Tnfrc
# 1                       22.0           5:15:45 h   Roberto Echeverría
# 2                       22.0           5:16:44 h    Puro Trail Osorno
# 3                       22.0           5:34:13 h             Columbia
# 4                       22.0           5:54:14 h       Baguales Trail
# 5                       22.0           6:25:01 h                  NaN
# 6                       22.0           6:28:00 h        Los Patagones
# 7                       22.0           6:32:24 h       Reaktiva Chile
# 8                       22.0           6:39:08 h    Puro Trail Osorno
# 9                       22.0           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286         0.0
# 1                 9.501         1.0
# 2                 9.472         2.0
# 3                 8.976         3.0
# 4                 8.469         4.0
# 5                 7.792         5.0
# 6                 7.732         6.0
# 7                 7.645         7.0
# 8                 7.516         8.0
# 9                 7.404         9.0

# %%
df.shape
# Out:
# (3505553, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                   float64
# dtype: object

# %%
#clean up data

# %%
#only USA and 50k or 50M in 2020

# %%
df[df['Event distance/length'] == "50km"]
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 3504895           2022  25.09.2022         Angevine Farm 50 km Race (USA)
# 3505438           2022  24.09.2022  Radioaseman Ultra Maraton 50 km (FIN)
# 3505439           2022  24.09.2022  Radioaseman Ultra Maraton 50 km (FIN)
# 3505440           2022  24.09.2022  Radioaseman Ultra Maraton 50 km (FIN)
# 3505441           2022  24.09.2022  Radioaseman Ultra Maraton 50 km (FIN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                       22.0           4:51:39 h
# 1                        50km                       22.0           5:15:45 h
# 2                        50km                       22.0           5:16:44 h
# 3                        50km                       22.0           5:34:13 h
# 4                        50km                       22.0           5:54:14 h
# ...                       ...                        ...                 ...
# 3504895                  50km                        6.0           7:29:36 h
# 3505438                  50km                        4.0           4:46:28 h
# 3505439                  50km                        4.0           4:56:15 h
# 3505440                  50km                        4.0           5:19:59 h
# 3505441                  50km                        4.0           5:19:59 h
#
#                   Athlete club Athlete country  Athlete year of birth  \
# 0                        Tnfrc             CHI                 1978.0
# 1           Roberto Echeverría             CHI                 1981.0
# 2            Puro Trail Osorno             CHI                 1987.0
# 3                     Columbia             ARG                 1976.0
# 4               Baguales Trail             CHI                 1992.0
# ...                        ...             ...                    ...
# 3504895           *Norwalk, CT             USA                 1981.0
# 3505438  Nocando Marathon Club             FIN                 1973.0
# 3505439     Pori Trail Runners             FIN                 1983.0
# 3505440        TT Treenitehdas             FIN                 1969.0
# 3505441       APK-Maratoonarit             FIN                    NaN
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286         0.0
# 1                    M                  M35                 9.501         1.0
# 2                    M                  M23                 9.472         2.0
# 3                    M                  M40                 8.976         3.0
# 4                    M                  M23                 8.469         4.0
# ...                ...                  ...                   ...         ...
# 3504895              M                  M40                 6.673    919343.0
# 3505438              M                  M45                10.472    618515.0
# 3505439              F                  W35                10.127     88177.0
# 3505440              M                  M50                 9.375   1022702.0
# 3505441              F                  NaN                 9.375    926478.0
#
# [777537 rows x 13 columns]

# %%
df[df['Event distance/length'] == "50mi"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 3504646           2022  25.09.2022
# 3504647           2022  25.09.2022
# 3505435           2022  24.09.2022
# 3505436           2022  24.09.2022
# 3505437           2022  24.09.2022
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 3504646               Vermont 50 Miles Ultra Run (USA)                  50mi
# 3504647               Vermont 50 Miles Ultra Run (USA)                  50mi
# 3505435      Radioaseman Ultra Maraton 50 mailia (FIN)                  50mi
# 3505436      Radioaseman Ultra Maraton 50 mailia (FIN)                  50mi
# 3505437      Radioaseman Ultra Maraton 50 mailia (FIN)                  50mi
#
#          Event number of finishers Athlete performance  \
# 55                             9.0           9:53:05 h
# 56                             9.0          11:09:35 h
# 57                             9.0          11:33:00 h
# 58                             9.0          11:38:17 h
# 59                             9.0          11:56:35 h
# ...                            ...                 ...
# 3504646                      115.0          12:11:12 h
# 3504647                      115.0          12:11:13 h
# 3505435                        3.0           8:35:44 h
# 3505436                        3.0           9:27:42 h
# 3505437                        3.0          10:20:08 h
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 55                *Middleville, MI             USA                 1983.0
# 56                   *Waterloo, ON             CAN                 1977.0
# 57                  *Kitchener, ON             CAN                 1976.0
# 58                      *Utica, MI             USA                 1986.0
# 59                 *Grass Lake, MI             USA                 1988.0
# ...                            ...             ...                    ...
# 3504646                        NaN             USA                    NaN
# 3504647                        NaN             USA                    NaN
# 3505435  Honkajoen Seudun Urhei...             FIN                 1979.0
# 3505436                  Ikaalinen             FIN                 1968.0
# 3505437               Team Nisulat             FIN                 1991.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 55                   M                  M23                 8.141        55.0
# 56                   F                  W40                 7.211        56.0
# 57                   M                  M40                 6.967        57.0
# 58                   M                  M23                 6.914        58.0
# 59                   M                  M23                 6.738        59.0
# ...                ...                  ...                   ...         ...
# 3504646              M                  NaN                 6.603   1022480.0
# 3504647              M                  NaN                 6.603   1022481.0
# 3505435              M                  M40                 9.361    959322.0
# 3505436              M                  M50                 8.505    995628.0
# 3505437              M                  M23                 7.785    988151.0
#
# [127580 rows x 13 columns]

# %%
df[df['Event distance/length'].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                                 Event name  \
# 0                 2018  06.01.2018                        Selva Costera (CHI)
# 1                 2018  06.01.2018                        Selva Costera (CHI)
# 2                 2018  06.01.2018                        Selva Costera (CHI)
# 3                 2018  06.01.2018                        Selva Costera (CHI)
# 4                 2018  06.01.2018                        Selva Costera (CHI)
# ...                ...         ...                                        ...
# 3505437           2022  24.09.2022  Radioaseman Ultra Maraton 50 mailia (FIN)
# 3505438           2022  24.09.2022      Radioaseman Ultra Maraton 50 km (FIN)
# 3505439           2022  24.09.2022      Radioaseman Ultra Maraton 50 km (FIN)
# 3505440           2022  24.09.2022      Radioaseman Ultra Maraton 50 km (FIN)
# 3505441           2022  24.09.2022      Radioaseman Ultra Maraton 50 km (FIN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                       22.0           4:51:39 h
# 1                        50km                       22.0           5:15:45 h
# 2                        50km                       22.0           5:16:44 h
# 3                        50km                       22.0           5:34:13 h
# 4                        50km                       22.0           5:54:14 h
# ...                       ...                        ...                 ...
# 3505437                  50mi                        3.0          10:20:08 h
# 3505438                  50km                        4.0           4:46:28 h
# 3505439                  50km                        4.0           4:56:15 h
# 3505440                  50km                        4.0           5:19:59 h
# 3505441                  50km                        4.0           5:19:59 h
#
#                   Athlete club Athlete country  Athlete year of birth  \
# 0                        Tnfrc             CHI                 1978.0
# 1           Roberto Echeverría             CHI                 1981.0
# 2            Puro Trail Osorno             CHI                 1987.0
# 3                     Columbia             ARG                 1976.0
# 4               Baguales Trail             CHI                 1992.0
# ...                        ...             ...                    ...
# 3505437           Team Nisulat             FIN                 1991.0
# 3505438  Nocando Marathon Club             FIN                 1973.0
# 3505439     Pori Trail Runners             FIN                 1983.0
# 3505440        TT Treenitehdas             FIN                 1969.0
# 3505441       APK-Maratoonarit             FIN                    NaN
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286         0.0
# 1                    M                  M35                 9.501         1.0
# 2                    M                  M23                 9.472         2.0
# 3                    M                  M40                 8.976         3.0
# 4                    M                  M23                 8.469         4.0
# ...                ...                  ...                   ...         ...
# 3505437              M                  M23                 7.785    988151.0
# 3505438              M                  M45                10.472    618515.0
# 3505439              F                  W35                10.127     88177.0
# 3505440              M                  M50                 9.375   1022702.0
# 3505441              F                  NaN                 9.375    926478.0
#
# [905117 rows x 13 columns]

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] ==2018)]
# Out:
#         Year of event     Event dates                 Event name  \
# 0                2018      06.01.2018        Selva Costera (CHI)
# 1                2018      06.01.2018        Selva Costera (CHI)
# 2                2018      06.01.2018        Selva Costera (CHI)
# 3                2018      06.01.2018        Selva Costera (CHI)
# 4                2018      06.01.2018        Selva Costera (CHI)
# ...               ...             ...                        ...
# 661478           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661479           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661480           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661481           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661482           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 0                       50km                       22.0           4:51:39 h
# 1                       50km                       22.0           5:15:45 h
# 2                       50km                       22.0           5:16:44 h
# 3                       50km                       22.0           5:34:13 h
# 4                       50km                       22.0           5:54:14 h
# ...                      ...                        ...                 ...
# 661478                  50mi                       29.0          17:05:58 h
# 661479                  50mi                       29.0          18:13:01 h
# 661480                  50mi                       29.0          18:49:58 h
# 661481                  50mi                       29.0          23:30:00 h
# 661482                  50mi                       29.0          25:40:10 h
#
#               Athlete club Athlete country  Athlete year of birth  \
# 0                    Tnfrc             CHI                 1978.0
# 1       Roberto Echeverría             CHI                 1981.0
# 2        Puro Trail Osorno             CHI                 1987.0
# 3                 Columbia             ARG                 1976.0
# 4           Baguales Trail             CHI                 1992.0
# ...                    ...             ...                    ...
# 661478                 NaN             USA                 1972.0
# 661479                 NaN             USA                 1953.0
# 661480                 NaN             USA                 1986.0
# 661481                 NaN             USA                 1952.0
# 661482                 NaN             USA                 1951.0
#
#        Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                   M                  M35                10.286         0.0
# 1                   M                  M35                 9.501         1.0
# 2                   M                  M23                 9.472         2.0
# 3                   M                  M40                 8.976         3.0
# 4                   M                  M23                 8.469         4.0
# ...               ...                  ...                   ...         ...
# 661478              M                  M45                 4.706     68122.0
# 661479              M                  M65                 4.417     23336.0
# 661480              M                  M23                 4.273    375022.0
# 661481              M                  M65                 3.424     68273.0
# 661482              M                  M65                 3.135    341648.0
#
# [167243 rows x 13 columns]

# %%
df[df['Event name'] == 'Yankee Springs 50 Mile Winter Challenge (USA)']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 3175861           2022  08.01.2022
# 3175862           2022  08.01.2022
# 3175863           2022  08.01.2022
# 3175864           2022  08.01.2022
# 3175865           2022  08.01.2022
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 3175861  Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 3175862  Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 3175863  Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 3175864  Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 3175865  Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
#
#          Event number of finishers Athlete performance       Athlete club  \
# 55                             9.0           9:53:05 h   *Middleville, MI
# 56                             9.0          11:09:35 h      *Waterloo, ON
# 57                             9.0          11:33:00 h     *Kitchener, ON
# 58                             9.0          11:38:17 h         *Utica, MI
# 59                             9.0          11:56:35 h    *Grass Lake, MI
# ...                            ...                 ...                ...
# 3175861                       15.0          11:39:57 h    *Birmingham, MI
# 3175862                       15.0          11:56:19 h  *Grand Rapids, MI
# 3175863                       15.0          13:00:31 h  *Byron center, MI
# 3175864                       15.0          13:10:13 h      *Brighton, MI
# 3175865                       15.0          13:40:59 h    *Barrington, IL
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 3175861             USA                 1992.0              F
# 3175862             USA                 1977.0              F
# 3175863             USA                 1994.0              M
# 3175864             USA                 1988.0              M
# 3175865             USA                 1958.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141        55.0
# 56                       W40                 7.211        56.0
# 57                       M40                 6.967        57.0
# 58                       M23                 6.914        58.0
# 59                       M23                 6.738        59.0
# ...                      ...                   ...         ...
# 3175861                  W23                 6.898    271782.0
# 3175862                  W40                  6.74        62.0
# 3175863                  M23                 6.186    815877.0
# 3175864                  M23                  6.11    845432.0
# 3175865                  M60                 5.881     56880.0
#
# [96 rows x 13 columns]

# %%
df[df['Event name'] == 'Yankee Springs 50 Mile Winter Challenge (USA)']['Event name'].str.split('(')
# Out:
# 55         [Yankee Springs 50 Mile Winter Challenge , USA)]
# 56         [Yankee Springs 50 Mile Winter Challenge , USA)]
# 57         [Yankee Springs 50 Mile Winter Challenge , USA)]
# 58         [Yankee Springs 50 Mile Winter Challenge , USA)]
# 59         [Yankee Springs 50 Mile Winter Challenge , USA)]
#                                  ...
# 3175861    [Yankee Springs 50 Mile Winter Challenge , USA)]
# 3175862    [Yankee Springs 50 Mile Winter Challenge , USA)]
# 3175863    [Yankee Springs 50 Mile Winter Challenge , USA)]
# 3175864    [Yankee Springs 50 Mile Winter Challenge , USA)]
# 3175865    [Yankee Springs 50 Mile Winter Challenge , USA)]
# Name: Event name, Length: 96, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 3504891           2022  25.09.2022
# 3504892           2022  25.09.2022
# 3504893           2022  25.09.2022
# 3504894           2022  25.09.2022
# 3504895           2022  25.09.2022
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 3504891                 Angevine Farm 50 km Race (USA)                  50km
# 3504892                 Angevine Farm 50 km Race (USA)                  50km
# 3504893                 Angevine Farm 50 km Race (USA)                  50km
# 3504894                 Angevine Farm 50 km Race (USA)                  50km
# 3504895                 Angevine Farm 50 km Race (USA)                  50km
#
#          Event number of finishers Athlete performance       Athlete club  \
# 55                             9.0           9:53:05 h   *Middleville, MI
# 56                             9.0          11:09:35 h      *Waterloo, ON
# 57                             9.0          11:33:00 h     *Kitchener, ON
# 58                             9.0          11:38:17 h         *Utica, MI
# 59                             9.0          11:56:35 h    *Grass Lake, MI
# ...                            ...                 ...                ...
# 3504891                        6.0           6:47:29 h     *Manalapan, NJ
# 3504892                        6.0           6:48:41 h   *Northampton, MA
# 3504893                        6.0           7:00:47 h      *Harrison, NJ
# 3504894                        6.0           7:28:56 h  *Spring Mills, PA
# 3504895                        6.0           7:29:36 h       *Norwalk, CT
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 3504891             USA                 1995.0              M
# 3504892             USA                 1978.0              M
# 3504893             USA                 1990.0              M
# 3504894             USA                 1992.0              F
# 3504895             USA                 1981.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141        55.0
# 56                       W40                 7.211        56.0
# 57                       M40                 6.967        57.0
# 58                       M23                 6.914        58.0
# 59                       M23                 6.738        59.0
# ...                      ...                   ...         ...
# 3504891                  M23                 7.362    863326.0
# 3504892                  M40                 7.341     69515.0
# 3504893                  M23                  7.13    766971.0
# 3504894                  W23                 6.683    322200.0
# 3504895                  M40                 6.673    919343.0
#
# [619016 rows x 13 columns]

# %%
df2 =df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] ==2018) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df2.head(10)
# Out:
#     Year of event Event dates                                     Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 60           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 61           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 62           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 63           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 64           2018  06.01.2018    Yankee Springs 50 km Winter Challenge (USA)
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                        9.0           9:53:05 h
# 56                  50mi                        9.0          11:09:35 h
# 57                  50mi                        9.0          11:33:00 h
# 58                  50mi                        9.0          11:38:17 h
# 59                  50mi                        9.0          11:56:35 h
# 60                  50mi                        9.0          12:32:16 h
# 61                  50mi                        9.0          12:39:36 h
# 62                  50mi                        9.0          12:39:36 h
# 63                  50mi                        9.0          13:24:05 h
# 64                  50km                       36.0           5:09:40 h
#
#          Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 55   *Middleville, MI             USA                 1983.0              M
# 56      *Waterloo, ON             CAN                 1977.0              F
# 57     *Kitchener, ON             CAN                 1976.0              M
# 58         *Utica, MI             USA                 1986.0              M
# 59    *Grass Lake, MI             USA                 1988.0              M
# 60        *Olaton, KY             USA                 1995.0              M
# 61       *Wyoming, MI             USA                 1979.0              M
# 62  *Grand Rapids, MI             USA                 1977.0              F
# 63       *Lansing, MI             USA                 1990.0              F
# 64        *Okemos, MI             USA                 1991.0              F
#
#    Athlete age category Athlete average speed  Athlete ID
# 55                  M23                 8.141        55.0
# 56                  W40                 7.211        56.0
# 57                  M40                 6.967        57.0
# 58                  M23                 6.914        58.0
# 59                  M23                 6.738        59.0
# 60                 MU23                 6.418        60.0
# 61                  M35                 6.356        61.0
# 62                  W40                 6.356        62.0
# 63                  W23                 6.004        63.0
# 64                  W23                 9.688        64.0

# %%
df2.shape
# Out:
# (64299, 13)

# %%
#remove USA from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 55        Yankee Springs 50 Mile Winter Challenge
# 56        Yankee Springs 50 Mile Winter Challenge
# 57        Yankee Springs 50 Mile Winter Challenge
# 58        Yankee Springs 50 Mile Winter Challenge
# 59        Yankee Springs 50 Mile Winter Challenge
#                             ...
# 661478                        Cactus Rose 50 Mile
# 661479                        Cactus Rose 50 Mile
# 661480                        Cactus Rose 50 Mile
# 661481                        Cactus Rose 50 Mile
# 661482                        Cactus Rose 50 Mile
# Name: Event name, Length: 64299, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# /tmp/ipython-input-3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(10)
# Out:
#     Year of event Event dates                                Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 60           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 61           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 62           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 63           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 64           2018  06.01.2018    Yankee Springs 50 km Winter Challenge
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                        9.0           9:53:05 h
# 56                  50mi                        9.0          11:09:35 h
# 57                  50mi                        9.0          11:33:00 h
# 58                  50mi                        9.0          11:38:17 h
# 59                  50mi                        9.0          11:56:35 h
# 60                  50mi                        9.0          12:32:16 h
# 61                  50mi                        9.0          12:39:36 h
# 62                  50mi                        9.0          12:39:36 h
# 63                  50mi                        9.0          13:24:05 h
# 64                  50km                       36.0           5:09:40 h
#
#          Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 55   *Middleville, MI             USA                 1983.0              M
# 56      *Waterloo, ON             CAN                 1977.0              F
# 57     *Kitchener, ON             CAN                 1976.0              M
# 58         *Utica, MI             USA                 1986.0              M
# 59    *Grass Lake, MI             USA                 1988.0              M
# 60        *Olaton, KY             USA                 1995.0              M
# 61       *Wyoming, MI             USA                 1979.0              M
# 62  *Grand Rapids, MI             USA                 1977.0              F
# 63       *Lansing, MI             USA                 1990.0              F
# 64        *Okemos, MI             USA                 1991.0              F
#
#    Athlete age category Athlete average speed  Athlete ID
# 55                  M23                 8.141        55.0
# 56                  W40                 7.211        56.0
# 57                  M40                 6.967        57.0
# 58                  M23                 6.914        58.0
# 59                  M23                 6.738        59.0
# 60                 MU23                 6.418        60.0
# 61                  M35                 6.356        61.0
# 62                  W40                 6.356        62.0
# 63                  W23                 6.004        63.0
# 64                  W23                 9.688        64.0

# %%
#clean up the althete age

# %%
df2 ['Athlete_age'] = 2018 - df2['Athlete year of birth']
# Out:
# /tmp/ipython-input-3523140396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2 ['Athlete_age'] = 2018 - df2['Athlete year of birth']

# %%
#remove h from athlete performance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# /tmp/ipython-input-2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(5)
# Out:
#     Year of event Event dates                                Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                        9.0             9:53:05
# 56                  50mi                        9.0            11:09:35
# 57                  50mi                        9.0            11:33:00
# 58                  50mi                        9.0            11:38:17
# 59                  50mi                        9.0            11:56:35
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 55  *Middleville, MI             USA                 1983.0              M
# 56     *Waterloo, ON             CAN                 1977.0              F
# 57    *Kitchener, ON             CAN                 1976.0              M
# 58        *Utica, MI             USA                 1986.0              M
# 59   *Grass Lake, MI             USA                 1988.0              M
#
#    Athlete age category Athlete average speed  Athlete ID  Athlete_age
# 55                  M23                 8.141        55.0         35.0
# 56                  W40                 7.211        56.0         41.0
# 57                  M40                 6.967        57.0         42.0
# 58                  M23                 6.914        58.0         32.0
# 59                  M23                 6.738        59.0         30.0

# %%
# drop columns: Athelte country, athlete age category, Athlete year of birth , Athlete  Club

# %%
df2 = df2.drop(['Athlete club', 'Athlete country' ,'Athlete year of birth' ,'Athlete age category'],axis=1)

# %%
df2.head(5)
# Out:
#     Year of event Event dates                                Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                        9.0             9:53:05
# 56                  50mi                        9.0            11:09:35
# 57                  50mi                        9.0            11:33:00
# 58                  50mi                        9.0            11:38:17
# 59                  50mi                        9.0            11:56:35
#
#    Athlete gender Athlete average speed  Athlete ID  Athlete_age
# 55              M                 8.141        55.0         35.0
# 56              F                 7.211        56.0         41.0
# 57              M                 6.967        57.0         42.0
# 58              M                 6.914        58.0         32.0
# 59              M                 6.738        59.0         30.0

# %%
#clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athlete_age                  575
# dtype: int64

# %%
df2[df2['Athlete_age'].isna()==1]
# Out:
#         Year of event Event dates                       Event name  \
# 453              2018  01.01.2018                    Red Eye 50km
# 456              2018  01.01.2018                    Red Eye 50km
# 459              2018  01.01.2018                    Red Eye 50km
# 460              2018  01.01.2018                    Red Eye 50km
# 13214            2018  17.03.2018  Lt. JC Stone 50K UltraMarathon
# ...               ...         ...                              ...
# 659684           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659685           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659688           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659689           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659690           2018  27.10.2018      Lake Hodges Trail Fest 50K
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 453                     50km                       21.0             5:10:00
# 456                     50km                       21.0             5:44:00
# 459                     50km                       21.0             6:07:00
# 460                     50km                       21.0             6:12:00
# 13214                   50km                       34.0             4:54:43
# ...                      ...                        ...                 ...
# 659684                  50km                      133.0             8:24:14
# 659685                  50km                      133.0             8:25:12
# 659688                  50km                      133.0             8:29:59
# 659689                  50km                      133.0             8:31:30
# 659690                  50km                      133.0             8:35:28
#
#        Athlete gender Athlete average speed  Athlete ID  Athlete_age
# 453                 M                 9.677       453.0          NaN
# 456                 M                 8.721       456.0          NaN
# 459                 M                 8.174       459.0          NaN
# 460                 M                 8.065       460.0          NaN
# 13214               F                10.179     12483.0          NaN
# ...               ...                   ...         ...          ...
# 659684              F                  5.95    374269.0          NaN
# 659685              F                 5.938    358717.0          NaN
# 659688              M                 5.883    204804.0          NaN
# 659689              F                 5.865    374272.0          NaN
# 659690              M                  5.82    374273.0          NaN
#
# [575 rows x 10 columns]

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (63724, 10)

# %%
# check for duplicates

# %%
df2[df2.duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete_age]
# Index: []

# %%
df2.reset_index(drop=True)
# Out:
#        Year of event     Event dates  \
# 0               2018      06.01.2018
# 1               2018      06.01.2018
# 2               2018      06.01.2018
# 3               2018      06.01.2018
# 4               2018      06.01.2018
# ...              ...             ...
# 63719           2018  27.-28.10.2018
# 63720           2018  27.-28.10.2018
# 63721           2018  27.-28.10.2018
# 63722           2018  27.-28.10.2018
# 63723           2018  27.-28.10.2018
#
#                                      Event name Event distance/length  \
# 0      Yankee Springs 50 Mile Winter Challenge                   50mi
# 1      Yankee Springs 50 Mile Winter Challenge                   50mi
# 2      Yankee Springs 50 Mile Winter Challenge                   50mi
# 3      Yankee Springs 50 Mile Winter Challenge                   50mi
# 4      Yankee Springs 50 Mile Winter Challenge                   50mi
# ...                                         ...                   ...
# 63719                      Cactus Rose 50 Mile                   50mi
# 63720                      Cactus Rose 50 Mile                   50mi
# 63721                      Cactus Rose 50 Mile                   50mi
# 63722                      Cactus Rose 50 Mile                   50mi
# 63723                      Cactus Rose 50 Mile                   50mi
#
#        Event number of finishers Athlete performance Athlete gender  \
# 0                            9.0             9:53:05              M
# 1                            9.0            11:09:35              F
# 2                            9.0            11:33:00              M
# 3                            9.0            11:38:17              M
# 4                            9.0            11:56:35              M
# ...                          ...                 ...            ...
# 63719                       29.0            17:05:58              M
# 63720                       29.0            18:13:01              M
# 63721                       29.0            18:49:58              M
# 63722                       29.0            23:30:00              M
# 63723                       29.0            25:40:10              M
#
#       Athlete average speed  Athlete ID  Athlete_age
# 0                     8.141        55.0         35.0
# 1                     7.211        56.0         41.0
# 2                     6.967        57.0         42.0
# 3                     6.914        58.0         32.0
# 4                     6.738        59.0         30.0
# ...                     ...         ...          ...
# 63719                 4.706     68122.0         46.0
# 63720                 4.417     23336.0         65.0
# 63721                 4.273    375022.0         32.0
# 63722                 3.424     68273.0         66.0
# 63723                 3.135    341648.0         67.0
#
# [63724 rows x 10 columns]

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                   float64
# Athlete_age                  float64
# dtype: object

# %%
df2['Athlete_age'] = df2['Athlete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                   float64
# Athlete_age                    int64
# dtype: object

# %%
#rename columns
#Year of event          Year_of_event
#Event dates	          Event_dates
#Event name	            Event_name
#Event distance/length	Event_distance/length
#Event number of finishers Event_number_of_finishers
#Athlete performance	  Athlete_performance
#Athlete gender	        Athlete_gender
#Athlete average speed	Athlete_average_speed
#Athlete ID	            Athlete_ID
